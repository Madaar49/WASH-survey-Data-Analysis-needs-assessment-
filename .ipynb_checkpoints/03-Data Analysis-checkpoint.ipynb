# %% [markdown]
# <img src="https://www.tu-darmstadt.de/media/resources/images_1/tu_logo_web.svg" width="200">
#
# ___
#
# ## Project Title:
# ### Analysis of WASH Data in Sierra Leone
# ___

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# #### 01- Data Cleaning

# %% [markdown]
# **Objective :** This notebook aims at data cleaning and preparation for visualization. Tasks listed in the `01-Exploratory Data Analysis` notebook will be adressed here
# ___

# %% [markdown]
# ### Recall: Listing all tasks
# * Selecting informative columns [pending task 1]
# * Cleaning Column Names [pending task 2]
# * Nesting the huge unique value count in the categorical features [pending task 3]
# * Splitting columns with categorical code and answers [pending task 4]
# * Extracting Location data [pending task 5]
# * Converting dataset from a pandas to a geodataframe [pending task 6]

# %%
import numpy as np
import pandas as pd
import os
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import contextily as ctx
# %matplotlib inline

# Auto reloads notebook when changes are made
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Introduction of the Adminstrative boundaries as shapefiles
# Since the best way to visualise all our datapoint is spatially, two shapefiles are introduced in the project. These are District and Chiefdoms. see <a href="https://www.mappr.co/counties/sierra-leone-provinces/#:~:text=As%20of%202017%2C%20there%20are%2016%20Sierra%20Leone,190%20chiefdoms%2C%20which%20perform%20some%20local%20government%20functions.">Sierra Leone Adminsitrative divisions</a>
#
#
# **District :** Administrative divisions of the country into 16 districts boundaries. The Districts are also a subset of 5 regions. For this study, we merge the Northern and North-Western Regions as one
#
# **Chiefdoms :** Are further subdivision of the Districts in the country. there are 190 chiefdoms in the country as of 2017 and 149 chiefdoms prior to this date.
#
# Because the survey took place before 2017, therefore administrative boundaries that preceeded the above named data will be used for analysis

# %%
#Importing shapefiles
df_1 = gpd.read_file('Shapefiles/SL_Districts.shp',index_col=0)
df_2 = gpd.read_file('Shapefiles/SL_Chiefdoms.shp',index_col=0)

# %%
## choosing informative columns in shapefiles
## 1. District shapefile
sl_dis = df_1[['name_0', 'name_1','name_2','geometry']]
sl_dis.columns = ['Country','Province','District', 'geometry']

## 2. Chiefdom shapefile
sl_chief = df_2[['name_0', 'name_1','name_2','name_3','geometry']]
sl_chief.columns = ['Country','Province','District','chiefdom', 'geometry']

#checking the CRS
sl_chief.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Importing Master dataset

# %%
## importing dataset as 'data'
data = pd.read_csv('WP_ALL DATA/WP Master.csv')
print('The shape of the merged data is :', data.shape)
data.head(2)
# Out:
# The shape of the merged data is : (26207, 52)
#             Submission Date 16230052|EA number 7420032|Community Name  \
# 0  30-07-2016 19:55:22 CEST                 14                 semabu
# 1   01-01-2016 21:16:53 CET                  7                mabonto
#
#   7430032|Water point Name                       5420051|Location  \
# 0           Community pump  South|Bonthe|Bonthe Urban|Bonthe Town
# 1           magburaka road         Tonkolili|Kafe Simiria|Mabonto
#
#    2420047|Latitude  --GEOLON--|Longitude --GEOELE--|Elevation  \
# 0          7.523658            -12.500999                   50
# 1          8.860831            -11.812625                150.1
#
#   --GEOCODE--|Geo Code                                      4430050|Photo  \
# 0             9lmqrpu9  https://akvoflow-110.s3.amazonaws.com/images/d...
# 1             bb270dny  https://akvoflow-110.s3.amazonaws.com/images/e...
#
#    ... 8480002|Are there trained natural ODF leaders in this community?  \
# 0  ...                                             <Null>
# 1  ...                                             <Null>
#
#   1530002|Are the trained natural ODF leaders performing their role effectively?  \
# 0                                             <Null>
# 1                                             <Null>
#
#            4690001|Observations about toilet  \
# 0  7:No toilet in household / not applicable
# 1                        6:Toilet looks good
#
#   6740003|Observe presence of water at the specific place for hand washing  \
# 0                           2:Water is not available
# 1                           2:Water is not available
#
#   3830002|Observe what device is present for hand washing  \
# 0                                1:No device present
# 1                                1:No device present
#
#   3810002|Record if soap or detergent is present at the specific place for hand washing  \
# 0                                             5:None
# 1                                             5:None
#
#                             Field49     chiefdom   District    Region
# 0   72849e96c5fe978793072373c77cae1         Dema     Bonthe  Southern
# 1  f0563f79f4dcc28f9d5877242bffc0f7  Kafe Simira  Tonkolili  Northern
#
# [2 rows x 52 columns]

# %% [markdown]
# ### Extracting Location data [pending task 5]

# %%
# Seperating District and Chiefdom from Location
### The code below had difficulting in stripping as there are iconsistency in the chiefdoms and districts
''' df1['District'] = df1.Location.str.findall('Kenema|Port Loko|Western Rural|Bo\|Moyamba|Tonkolili\
                            |Bonthe|Kailahun|Bombali|Kambia|Kono|Koinadugu|Pujehun|Western Urban')
                            '''
''' Solution: I used the shapefiles 'sl_Dist' and 'sl_Chief' above and did spatial join in ArcGisPro
'''
# Out:
# " Solution: I used the shapefiles 'sl_Dist' and 'sl_Chief' above and did spatial join in ArcGisPro\n"

# %% [markdown]
# ### Converting dataset from a pandas to a geodataframe [Task 6]

# %%
# converting data to geodataframe
## Rename the longitude and latitude columns for conveniency
data.rename(columns={'2420047|Latitude':'latitude',
                     '--GEOLON--|Longitude':'longitude',
                     '5420051|Location':'Location'}, inplace=True)
# Inspecting Longitude/latitude coverage
## Sierra Leone lies within Latitude 8.460555 and longitude -11.779889
print('The minimum longitude is: ',data['longitude'].min())
print('The minimum latitude is: ',data['latitude'].min())
print('The number of columns is: ', len(data))

##converting df to GDF
df1 = gpd.GeoDataFrame(
    data, geometry=gpd.points_from_xy(data.longitude, data.latitude), crs= "EPSG:4326")
df1.head(2)
# Out:
# The minimum longitude is:  -13.292313
# The minimum latitude is:  6.932476
# The number of columns is:  26207
#             Submission Date 16230052|EA number 7420032|Community Name  \
# 0  30-07-2016 19:55:22 CEST                 14                 semabu
# 1   01-01-2016 21:16:53 CET                  7                mabonto
#
#   7430032|Water point Name                               Location  latitude  \
# 0           Community pump  South|Bonthe|Bonthe Urban|Bonthe Town  7.523658
# 1           magburaka road         Tonkolili|Kafe Simiria|Mabonto  8.860831
#
#    longitude --GEOELE--|Elevation --GEOCODE--|Geo Code  \
# 0 -12.500999                   50             9lmqrpu9
# 1 -11.812625                150.1             bb270dny
#
#                                        4430050|Photo  ...  \
# 0  https://akvoflow-110.s3.amazonaws.com/images/d...  ...
# 1  https://akvoflow-110.s3.amazonaws.com/images/e...  ...
#
#   1530002|Are the trained natural ODF leaders performing their role effectively?  \
# 0                                             <Null>
# 1                                             <Null>
#
#            4690001|Observations about toilet  \
# 0  7:No toilet in household / not applicable
# 1                        6:Toilet looks good
#
#   6740003|Observe presence of water at the specific place for hand washing  \
# 0                           2:Water is not available
# 1                           2:Water is not available
#
#   3830002|Observe what device is present for hand washing  \
# 0                                1:No device present
# 1                                1:No device present
#
#   3810002|Record if soap or detergent is present at the specific place for hand washing  \
# 0                                             5:None
# 1                                             5:None
#
#                             Field49     chiefdom   District    Region  \
# 0   72849e96c5fe978793072373c77cae1         Dema     Bonthe  Southern
# 1  f0563f79f4dcc28f9d5877242bffc0f7  Kafe Simira  Tonkolili  Northern
#
#                     geometry
# 0  POINT (-12.50100 7.52366)
# 1  POINT (-11.81263 8.86083)
#
# [2 rows x 53 columns]

# %% [markdown]
# ### Selecting informative columns [Task 1]

# %% [markdown]
# ### Cleaning Column Names [Task 2]
# {Unchanged}
# ('old name': `new name`)
# * {`Region`, `District`, `Chiefdom`,`Latitude`,`Longitude`,`Elevation`, `GEOCODE`, `Photo`}
# * ('Submission Date':`sub_date`)
# * ('7430032|Water point Name':`wp Name`)
# * ('4420041|Extraction system type': `extract_type`)
# * ('5450040|Type of water point':`wp_type`)
# * ('7430035|Water point Functionality': `wp_func`)
# * ('4390041|Is water available throughout the year?': `wp_sustain`)
# * ('6430039|Is/was this point monthly or regularly chlorinated?' :`chlorination`)
# * ('4430055|Year of construction': `const_year`)
# * ('4390044|Who owns the water point?': `ownership`)
# * ('7430040|Is there a trained mechanic available at this point?': `wp_mechanic`)
# * ('4380054|Who is maintaining the water point (routine repairs)?': `maintenance`)
# * ('7380052|Is there a WASH management committee?': `WASH_team`)
# * ('460037|How many minutes does it take to reach the nearest spare part supplier?': `t_toSpares?`)
# * (1500002|Has the community been declared ODF?': `commu_ODF?`)

# %%
#creating a dataframe with desired columns
df2 = df1[['Submission Date','Region','District','chiefdom',
       '7430032|Water point Name','latitude', 'longitude',
       '5450040|Type of water point', '4420041|Extraction system type',
       '440041|Pump type','7430035|Water point Functionality',
       '4380053|Last time the water point broke down, how long did it take to repair?',
       '6430039|Is/was this point monthly or regularly chlorinated?',
       '4390041|Is water available throughout the year?',
       '7420038|Is the water paid for at this point?',
       '4430055|Year of construction',
       '4390044|Who owns the water point?',
       '4380054|Who is maintaining the water point (routine repairs)?',
       '7380052|Is there a WASH management committee?',
       '510001|Is the WASH management committee functioning?',
       '7430040|Is there a trained mechanic available at this point?',
       '460037|How many minutes does it take to reach the nearest spare part supplier?',
       '1500002|Has the community been declared ODF?','geometry']]
## renaming columns
df2.columns = ['sub_date','Region','District', 'Chiefdom','wp name', 'latitude', 'longitude','wp_type',
                    'extract_type','pump_type','wp_func','repair_time','chlorination','wp_sustain','wp_billed',
                    'const_year','ownership','maintenance','WASH_team','WASHteam_func','wp_mechanic',
                    't_toSpares?','commu_ODF','geometry']
df2.describe()
print(df2.shape)
# Out:
# (26207, 24)

# %% [markdown]
# ### Splitting columns with categorical code and answers [Task 4]

# %%
#columns to clean
cols = ['Region', 'District','wp_type', 'wp_func', 'wp_sustain',
        'ownership','maintenance','WASHteam_func','pump_type',
        'WASH_team','extract_type','repair_time','wp_billed']

## clean the columns and assign the values back to the dataframe
df2[cols] = df2[cols].apply(lambda col: col.str.split(':', n=1).str.get(-1))
df2.head(2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                    sub_date    Region   District     Chiefdom         wp name  \
# 0  30-07-2016 19:55:22 CEST  Southern     Bonthe         Dema  Community pump
# 1   01-01-2016 21:16:53 CET  Northern  Tonkolili  Kafe Simira  magburaka road
#
#    latitude  longitude                wp_type extract_type      pump_type  \
# 0  7.523658 -12.500999  Tube well or borehole    Hand pump  India Mark II
# 1  8.860831 -11.812625       Protected spring       <Null>         <Null>
#
#    ...              wp_billed const_year  ownership  \
# 0  ...  No payment – its free       2012  Community
# 1  ...  No payment – its free       1987  Community
#
#                  maintenance WASH_team  WASHteam_func wp_mechanic t_toSpares?  \
# 0              No management   Unknown         <Null>     Unknown          85
# 1  WASH management committee       Yes            Yes         Yes         180
#
#     commu_ODF                   geometry
# 0  Don't know  POINT (-12.50100 7.52366)
# 1          No  POINT (-11.81263 8.86083)
#
# [2 rows x 24 columns]

# %% [markdown]
# ### Nesting the unique value count in the categorical features [pending Task 3]

# %% [markdown]
# #### Inspecting categorical features

# %%
## number of unique values in each feature
unique_values_by_col = pd.DataFrame(df2.nunique()) 
unique_values_by_col
# Out:
#                    0
# sub_date       25623
# Region             5
# District          15
# Chiefdom         152
# wp name        15499
# latitude       25560
# longitude      25611
# wp_type           92
# extract_type     176
# pump_type         12
# wp_func            6
# repair_time        7
# chlorination       4
# wp_sustain         3
# wp_billed         54
# const_year        76
# ownership         11
# maintenance      265
# WASH_team          3
# WASHteam_func      4
# wp_mechanic       31
# t_toSpares?      359
# commu_ODF          4
# geometry       26016

# %% [markdown]
# #### Methodology
# Several columns will be nested as they contain too many familiar categories. Below are the columns to be nested
#
# |Feature||unique values|
# |---||---|
# |wp_type||92|
# |extract_type||176|
# |pump_type||12|
# |wp_billed||54|
# |maintenance||265|
# |ownership||11|
# |wp_mech||31|
# |const_year||76|
# |WASHteam_func||4|
#
# **Details :** Three techniques will be used for nesting categories in columns
# * `.map`
# * `if-elif`
# * `regex replacements`
# choice of method will be done appropriately

# %% [markdown]
# ### 1. wp_type

# %%
## inspecting categories of 'wp type'
# pd.set_option ('display.max_rows', None)
print(df2['wp_type'].value_counts().to_dict())
# Out:
# {'Protected dug well': 12384, 'Public tap/standpipe (stand-alone or water kiosk': 4148, 'Unprotected dug well': 3993, 'Tube well or borehole': 2205, 'Piped water into dwelling/plot/yard': 1900, 'Sand/Sub-surface dam (with well or standpipe)': 498, 'Protected spring': 389, 'Surface water (lake/river/stream)': 187, 'Unprotected spring': 91, 'Unequipped borehole': 64, 'Rainwater (harvesting)': 59, 'Hand pump': 51, 'handpump': 31, 'Dam/pan (runoff harvesting)': 30, 'Handpump': 17, 'Protected Shallow Well': 15, 'hand pump': 11, '': 11, 'stand tap': 9, 'Gravity': 7, 'Drilled well': 5, 'water tank': 4, 'null': 4, 'local pump': 4, 'supplied by bowser': 4, 'Stand tap': 3, 'water trucking': 3, 'storage tank': 3, 'reservoir': 3, '10000L storage tank': 3, 'Tap Pump': 3, 'under construction': 2, 'Jake pump': 2, 'spring box': 2, 'Borehole': 2, 'hand pumps': 2, 'Tap': 2, 'stand pipe': 2, 'Emas drilled well': 1, 'gravitty': 1, '10000L Storage tank': 1, 'InComplete': 1, 'tap': 1, 'Tap water': 1, '10,000L Milla tank': 1, 'run through tap': 1, 'loca pump': 1, 'drilled well': 1, 'manual lift pump': 1, 'Under ground source': 1, 'no pump': 1, 'jack pump': 1, 'school quarter tap': 1, 'sub massive': 1, 'Borehole with uplift pump': 1, 'Unfinished Well': 1, 'Storage tank': 1, 'Also submersible.': 1, 'Water  well': 1, 'Protected bore.hole': 1, 'Unprotected Tank': 1, 'hand pump wells': 1, 'Under Construction': 1, 'Protected hand dug with submerssible pump': 1, 'run throigh t': 1, 'Underconstruction': 1, 'Colonial pump': 1, 'Spring Box': 1, 'hanfpump': 1, 'Water tank': 1, 'Pump removed water drown mannually': 1, 'water tank supply by bowser': 1, 'Gravity Tap': 1, '5000L storage tank': 1, 'jack Pump': 1, 'Protected dug well pump removed': 1, 'weir,no pipework': 1, 'supply by bowser': 1, 'Submasive pump': 1, 'protected shallow well': 1, 'protected drill well': 1, 'tank': 1, 'stream': 1, 'Bore hole': 1, 'hand. pump': 1, 'dam': 1, 'hamdpump': 1, 'Unprotected Pit': 1, '10,000L storage tank': 1, 'banda pump': 1, 'Under construction': 1, 'Open Hand dug well': 1}

# %%
## Since there are a lot of categories that can be melted into bigger categories, we create a new category 
# to do  this, we create a regex code
replacements = {
r'Protected dug well': 'protec dug_well',
r'Unprotected dug well': 'unprotec dug_well',
r'Public tap/standpipe (\stand-alone or water kiosk)\n': 'public tap/kiosk',
r'Tube well or borehole ': 'borewell',
r'Piped water into dwelling/plot/yard ': 'public tap in priv',
r'Sand/Sub-surface dam (with well or standpipe)': 'public tap',
r'Protected spring': 'spring_protec',
r'Surface water (lake/river/stream)': 'surface_water',
r'Unprotected spring': 'spring_unprotec',
r'Unequipped borehole':'borewell', 
r'Rainwater (harvesting)': 'rainwater_harvesting',
r'Protected Shallow Well': 'protec dug_well',
r'Dam/pan (runoff harvesting)': 'mini_gravity',
r'stand tap': 'public tap',
r'Gravity': 'gravity_scheme',
r'Drilled well': 'borewell',
r'Stand tap': 'public tap',
r'': 'public tap', 
r'Tap': 'public tap',
r'stand pipe': 'public tap',
r'Unprotected Tank': 'public tap',
r'protected drill well': 'public tap',
r'gravitty': 'gravity_scheme',
r'protected shallow well': 'protec dug_well',
r'Submasive pump': 'borewell', #Intution that submersive pumps are frequently installed in Borewells
r'tap': 'public tap',
r'Unfinished Well': 'unprotec dug_well', #Well is unfinished hence not protected
r'school quarter tap': 'public tap/kiosk', #classified as public since it is not in private area
r'drilled well': 'borewell',   
r'Emas drilled well': 'borewell', #well is drilled hence its a borewell
r'stream': 'surface_water',
r'Water tank': 'public tap', #water tanks are always connected to taps below the tanks                                            1
r'Open Hand dug well': 'unprotec dug_well',
r'Hand pump':'protec dug_well',  # this can also be categorized in borewell  
r'Water  well': 'unprotec dug_well', #purely based on intution
r'spring box': 'spring_protec',
r'Gravity Tap':'gravity_scheme',
r'Under ground source':'spring_unprotected',
r'dam':'gravity_scheme',
r'no pump':'unprotec dug_well',
r'Protected hand dug with submerssible pump':'protec dug_well',
r'Underconstruction':'protec dug_well', #assume it is being used manually
r'InComplete':'unprotec dug_well',
r'Under Construction':'unprotec dug_well',
r'storage tank':'public tap',
r'\-': '',
}

# %%
df2['wp_type'].replace(regex=replacements, inplace=True)
print(df2['wp_type'].value_counts().to_dict())
# Out:
# {'protec dug_well': 12453, 'Public public public tap/standpipe (standalone or water kiosk': 4148, 'unprotec dug_well': 3999, 'Tube well or borehole': 2205, 'Piped water into dwelling/plot/yard': 1900, 'Sand/Subsurface gravity_scheme (with well or standpipe)': 498, 'spring_protec': 391, 'Surface water (lake/river/surface_water)': 187, 'spring_unprotec': 91, 'borewell': 71, 'Rainwater (harvesting)': 59, 'handpump': 31, 'Dam/pan (runoff harvesting)': 30, 'public public tap': 22, 'Handpump': 17, 'public public public tap': 12, 'hand pump': 11, 'gravity_scheme': 9, 'water tank': 4, 'null': 4, 'supplied by bowser': 4, 'local pump': 4, '10000L public public tap': 3, 'water trucking': 3, 'reservoir': 3, 'public public tap Pump': 3, 'hand pumps': 2, 'under construction': 2, 'Jake pump': 2, 'Borehole': 2, 'sub massive': 1, 'Borehole with uplift pump': 1, 'public public tap water': 1, 'Storage tank': 1, 'Emas borewell': 1, '10,000L Milla tank': 1, 'run through public public tap': 1, 'school quarter public public tap': 1, 'Protected bore.hole': 1, 'loca pump': 1, 'Under construction': 1, '10000L Storage tank': 1, 'spring_unprotected': 1, 'jack pump': 1, 'Also submersible.': 1, 'jack Pump': 1, 'banda pump': 1, 'water tank supply by bowser': 1, 'hamdpump': 1, 'weir,no pipework': 1, 'Spring Box': 1, 'manual lift pump': 1, 'run throigh t': 1, 'Colonial pump': 1, 'hanfpump': 1, 'Pump removed water drown mannually': 1, 'gravity_scheme public public tap': 1, '10,000L public public tap': 1, '5000L public public tap': 1, 'protec dug_well pump removed': 1, 'supply by bowser': 1, 'tank': 1, 'surface_water': 1, 'Bore hole': 1, 'hand. pump': 1, 'Unprotected Pit': 1, 'hand pump wells': 1}

# %%
# There are now 67 categories hence this will be rescaled to 9 categories
def wtype_v(x):
    if (x == 'Handpump'or x == 'handpump'or x == 'hand pump'or x == 'protec dug_well'):
        return 'protected dug_well'
    elif (x =='Public public public tap/standpipe (standalone or water kiosk'
          or x == 'Piped water into dwelling/plot/yard'or x == 'public public public tap'
          or x == 'public public tap'or x == 'public public public tap'):
        return 'public tap/standpipe'
    elif (x == 'unprotec dug_well'):
        return 'Unprotected dug_well'
    elif (x == 'borewell'or x == 'Tube well or borehole'):
          return 'borewell'
    elif (x == 'Sand/Subsurface gravity_scheme (with well or standpipe)'
          or x == 'gravity_scheme'):
          return 'gravity scheme'
    elif (x == 'spring_protec'):
          return 'protected spring'
    elif (x == 'Rainwater (harvesting)' or x == 'Dam/pan (runoff harvesting)'):
          return 'rainwater harvesting'
    elif (x == 'water tank'):
          return 'water tank'
    else:
        return 'OTHER'
df2['wp_type'] = df2['wp_type'].apply(wtype_v)
print(df2['wp_type'].value_counts())
# Out:
# protected dug_well      12512
# public tap/standpipe     6082
# Unprotected dug_well     3999
# borewell                 2276
# gravity scheme            507
# protected spring          391
# OTHER                     347
# rainwater harvesting       89
# water tank                  4
# Name: wp_type, dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# ### maintenance

# %%
# rescaling the maintenance features. There are 199 categories hence this will be rescaled to 16 categories
def main_v(x):
    if (x == 'Community' or x == 'community people' or x == 'Community itself'
        or x == 'COMMUNITY' or x == 'community' or x == 'Community People'
        or x == 'Community leaders'or x == 'Community leaders'):
        return 'Community'
    elif (x == 'Privat owner Other' or x == 'WASH management committee'
          or x == 'School' or x == 'No management' or x == 'NGO' or x == 'Health Facility'
          or x == 'Uknown' or x == 'SALWACO' or x == 'Other Institution'
          or x == 'Local council' or x == 'GUMA'):
        return x 
    else:
        return 'other'
df2['maintenance'] = df2['maintenance'].apply(main_v)
print(df2['maintenance'].value_counts())
# Out:
# other                        13918
# WASH management committee     5340
# School                        1889
# No management                 1179
# Health Facility                675
# NGO                            619
# Uknown                         576
# SALWACO                        544
# Other Institution              474
# Community                      403
# Local council                  369
# GUMA                           221
# Name: maintenance, dtype: int64

# %% [markdown]
# ### extract_type

# %%
print(df2['extract_type'].value_counts().to_dict())
# Out:
# {'Hand pump': 12134, 'Hand manual (e.g. rope pump, rope & bucket)': 6075, 'Gravity': 3158, '<Null>': 2979, 'Hydram pump': 677, 'Submersible pump': 474, 'Surface pump': 89, 'tap': 71, 'run through tap': 54, 'RUN IN PIPE': 40, 'RUNS THROUGH TAP': 36, 'RUNNING TAP': 27, 'under construction': 27, 'RUN THROUGH PIPE': 21, 'Tap': 21, 'No pump': 18, '': 12, 'supplied by bowser': 12, 'water trucking': 11, 'Under construction': 9, 'pulley': 8, 'null': 8, 'RUN THROUGH TAP': 8, 'stand tap': 8, 'incomplete well': 8, 'on construction': 7, 'Unidentified': 6, 'stand pipe': 6, 'burn pipe': 6, 'TAP': 6, 'Under Construction': 6, 'stand post': 5, 'No hand pump': 5, 'On construction': 4, 'No Hand pump': 4, 'Run through tap': 3, 'pulley system': 3, 'Tap Pump': 3, 'stand taps': 3, '10000L Storage tank': 3, 'Stand pipe': 3, 'Unknown': 3, 'Hand pump stolen': 2, 'unknown': 2, 'THROUGH TAP': 2, 'run through pipe': 2, 'Public tap stand': 2, 'Broken down': 2, 'Under Rehabilitation': 2, 'stand pump': 2, 'on construction.': 2, 'Stolen Hand pump': 2, 'no pump': 2, 'Undefined': 2, 'no idea as to now': 1, 'Runs THROUGH TAP': 1, 'pulley systém': 1, 'water truking': 1, 'Stolen pump': 1, 'no water': 1, '10000L storage tank': 1, 'RUN IN PIPES': 1, 'Bore hole with solar panels': 1, 'Not in use': 1, 'Proposed hand pump': 1, 'still under construction': 1, 'Running tap': 1, 'unidentiried': 1, 'Not defined': 1, 'rope and bucket': 1, 'abandon well': 1, 'H2O RUN THROUGH PIPE': 1, 'never completed': 1, 'Stand Tap': 1, 'hand pump stolen': 1, 'No Pump': 1, 'no pump available.': 1, 'pipe burn': 1, 'run through tao': 1, 'rin through tap': 1, 'Well dry. Not water': 1, 'Abandon': 1, 'The well is with out handpump': 1, 'Well not in use': 1, 'No means': 1, 'No hand pump fix': 1, 'RUNNING WATER FROM TAP': 1, 'Damage well': 1, 'Tap pump': 1, 'mechanized pumping system': 1, 'public tap stand': 1, 'Rain Harvester': 1, 'Also mannually.': 1, 'run through tat': 1, 'Not in use at all cause the well is dry': 1, 'Water trucking': 1, 'Broken Down': 1, 'Stand post': 1, 'pump not yet fixed': 1, 'unfinished': 1, 'submersible': 1, 'Run through rim': 1, 'water run through tap': 1, 'Abandoned Project': 1, 'supplied by bowset': 1, 'Well dismantled by cord and not installed': 1, 'Not completed': 1, 'emersive pump': 1, 'No pumpavailable': 1, 'public tap': 1, 'run through rim': 1, 'Roap And Burcket': 1, 'supplied by bowsrr': 1, 'hand pump not present': 1, 'RUN IN  PIPE': 1, 'jack pump': 1, 'no pump has been installed': 1, 'Water runs through tap': 1, 'incomplete': 1, "Don't know": 1, '.not applicable': 1, 'bucket pump': 1, 'UNDER REHABILITATION': 1, 'supply by bowser': 1, 'use rope currently because hand pump is broken down': 1, 'THROUGH PIPE': 1, 'Mannual and sub.. mersive pump': 1, 'unidentified': 1, 'Solar Powered': 1, 'draw up by a machine': 1, 'Public Tap Stand': 1, 'hand pump is stolen.': 1, 'No access the water': 1, 'No pump present': 1, 'Not yet install': 1, 'splar power': 1, 'with out pump': 1, 'Not functional': 1, 'dam': 1, 'No pump have been install yet': 1, 'Degremont': 1, 'pump not available.': 1, 'Stand ing pump': 1, 'Hand pump not yet complete': 1, 'run through': 1, 'Mosque tap stands': 1, 'Yet under construction': 1, 'Dam': 1, 'Manual lift pump': 1, 'condemned by the community': 1, 'None above is applicable. Water well under construction': 1, 'not applicable': 1, 'no pump available': 1, 'Pump not install': 1, 'Tao': 1, 'Stand pump': 1, 'uncompleted well': 1, 'unfinished well': 1, 'rain harvesting and gravity': 1, 'Hand pump but stolen': 1, 'under Construction': 1, 'broken': 1, 'iack pump': 1, 'Damage pump': 1, 'unidentifry': 1, 'Pump broken down water got mannually': 1, 'Well condemned': 1, 'Incomplete awaiting pump installation': 1, 'it was intended to be connected to a submersible pump': 1, 'No system available': 1, 'Hand pump Stolen': 1, 'Mannually use as well.': 1, 'Dam connection': 1, 'not in use': 1, 'supplied bowser': 1, 'No pump installed': 1}

# %%
# rescaling the extract_type from 176 categories
def extyp_v(x):
    if (x == 'Hand pump' or x == 'Gravity' 
       or x == 'Hydram pump' or x == 'Submersible pump'
       or x == 'Surface pump'):
        return x 
    elif (x == 'Hand manual (e.g. rope pump, rope & bucket)'):
        return 'Hand manual (e.g. rope pump, rope & bucket)'
    elif (x == 'tap'or x == 'run through tap'or x == 'RUN IN PIPE'or 
          x == 'RUNS THROUGH TAP' or x == 'RUNNING TAP'or x == 'Tap'
          or x == 'RUN THROUGH PIPE'):
        return 'Tap'
    elif (x == 'supplied by bowser' or x == 'water trucking'):
        return 'Water Trucking'
    else:
        return 'OTHER'
df2['extract_type'] = df2['extract_type'].apply(extyp_v)
print(df2['extract_type'].value_counts())
# Out:
# Hand pump                                      12134
# Hand manual (e.g. rope pump, rope & bucket)     6075
# OTHER                                           3307
# Gravity                                         3158
# Hydram pump                                      677
# Submersible pump                                 474
# Tap                                              270
# Surface pump                                      89
# Water Trucking                                    23
# Name: extract_type, dtype: int64

# %% [markdown]
# ### pump_type

# %%
print(df2['pump_type'].value_counts().to_dict())
# Out:
# {'<Null>': 13984, 'India Mark II': 7428, 'Kardia': 1574, 'Unidentified': 945, 'PB Mark II': 693, 'India Mark': 539, 'Afridev': 390, 'Inkar': 238, 'India Mark III': 218, 'Bucket': 168, 'Vergnet footpump': 16, 'Consallen': 14}

# %%
## classifying <NULL> as <others>
df2['pump_type'] = df2['pump_type'].replace('<Null>', 'OTHER')
print(df2['pump_type'].value_counts())
# Out:
# OTHER               13984
# India Mark II        7428
# Kardia               1574
# Unidentified          945
# PB Mark II            693
# India Mark            539
# Afridev               390
# Inkar                 238
# India Mark III        218
# Bucket                168
# Vergnet footpump       16
# Consallen              14
# Name: pump_type, dtype: int64

# %% [markdown]
# ### wp_billed

# %%
print(df2['wp_billed'].value_counts().to_dict())
# Out:
# {'No payment – its free': 18098, '<Null>': 5901, 'Yes, Flat rate (LE/HH/month)': 1107, 'Only after system breakdown': 476, 'Yes, Per jerrican 20L': 462, 'Yes, Metered (LE/m3)': 106, 'Not Applicable': 5, 'No water': 3, 'water rate': 3, "Don't know": 2, 'by monthly payment': 1, 'Payment is done during services': 1, 'payment was stopped(flat rate)because there was a disruption on the flow of water due to road construction': 1, 'monthly  contribution': 1, '': 1, 'For now no payment': 1, 'payment made by year': 1, 'The pump is not fuctioning.': 1, 'GUMA COST': 1, 'only after distribution system broke down in2012': 1, 'it was advised by expert to to drink': 1, 'Under Construction': 1, 'point not used by community': 1, 'Monthly Contribution': 1, 'disruption on flow of water since 2012 due to road construction (payment on flat rate basis)': 1, 'system broke down': 1, 'it collected by pumping and distributed to part of the community and then paid for at a flat rate': 1, 'on construction': 1, 'null': 1, 'No  water': 1, 'no payment because ttansfer of property': 1, 'It is not free . people pay for it': 1, 'Pay 5000 if you break the law': 1, 'sometimes payment is done annually': 1, 'per container': 1, 'It was bought': 1, 'Contains Micro organisms': 1, '500.00per month per household': 1, 'Never water': 1, 'YEARLY': 1, 'spring water': 1, 'No payment but needs chlorine to supply to the community': 1, 'school property': 1, 'No idea as for now': 1, 'water has never supply': 1, 'No': 1, 'dont know': 1, 'Before, but  not now': 1, "don't known": 1, 'emergency purposes': 1, 'under construction': 1, 'Well dry': 1, 'No payment because of poor water supply': 1, 'the pumps are bought': 1}

# %%
# rescaling the maintenance features. There are 199 categories hence this will be rescaled to 16 categories
def wp_bill(x):
    if (x == 'No payment – its free'):
        return 'No payment' 
    elif (x == '<Null>'):
        return 'Unknown'
    elif (x == 'Yes, Flat rate (LE/HH/month)'):
        return 'Yes, Monthly'
    elif (x == 'Yes, Per jerrican 20L' or x == 'Yes, Metered (LE/m3)'):
        return x
    else:
        return 'OTHER'
df2['wp_billed'] = df2['wp_billed'].apply(wp_bill)
# df2.head()
print(df2['wp_billed'].value_counts())
# Out:
# No payment               18098
# Unknown                   5901
# Yes, Monthly              1107
# OTHER                      533
# Yes, Per jerrican 20L      462
# Yes, Metered (LE/m3)       106
# Name: wp_billed, dtype: int64

# %% [markdown]
# ### const_year

# %% [markdown]
# **Details :** Most of the well were constructed in the 2000's.
# After 2009, construction per year exceeds 1000. Therefore, no further classification
# was done after 2010

# %%
## convert year from string to numerical
# df2['const_year'] = df2['const_year'].apply(pd.to_numeric, errors='coerce', axis=1)
df2.const_year = df2.const_year.astype(int)
print(df2['const_year'].value_counts().to_dict())
# Out:
# {2013: 2008, 2012: 1712, 2014: 1663, 2016: 1626, 2015: 1577, 2010: 1540, 2011: 1391, 2008: 1086, 2009: 1052, 2003: 911, 2004: 899, 2005: 860, 1986: 837, 2006: 831, 2002: 784, 2007: 744, 2000: 717, 2001: 449, 1985: 438, 1990: 403, 1989: 353, 1987: 348, 1992: 321, 1988: 300, 1998: 287, 1999: 253, 1984: 249, 1980: 247, 1982: 242, 1930: 233, 1991: 213, 1996: 210, 1995: 183, 1994: 169, 1993: 132, 1997: 128, 1970: 120, 1983: 88, 1972: 68, 1978: 51, 1975: 49, 1976: 41, 1960: 40, 1981: 37, 1973: 35, 1945: 34, 1979: 27, 1950: 22, 1965: 20, 1962: 18, 1967: 17, 1974: 15, 1968: 13, 1977: 12, 1940: 11, 1956: 11, 1946: 10, 1971: 9, 2017: 7, 1964: 7, 1935: 6, 1955: 6, 1952: 6, 1954: 5, 1966: 3, 1961: 3, 1933: 3, 1963: 3, 1958: 2, 1943: 2, 1969: 2, 1932: 2, 1957: 2, 1942: 2, 1934: 1, 1931: 1}

# %%
# rescaling the const_year features from 76 categories to n
def cons_yr(x):
        if (x < 1950):
            return 'Before 1950'
        elif (x < 2000):
            return '1950 - 2000'
        elif (x < 2005):
            return '2001 - 2005'
        elif (x < 2010):
            return '2005 - 2010'
        else:
            return x
df2['const_yr'] = df2['const_year'].apply(cons_yr)
print(df2['const_yr'].value_counts())
# Out:
# 1950 - 2000    6045
# 2005 - 2010    4573
# 2001 - 2005    3760
# 2013           2008
# 2012           1712
# 2014           1663
# 2016           1626
# 2015           1577
# 2010           1540
# 2011           1391
# Before 1950     305
# 2017              7
# Name: const_yr, dtype: int64

# %% [markdown]
# ### wp_mechanic

# %%
print(df2['wp_mechanic'].value_counts().to_dict())
# Out:
# {'No': 12006, 'Yes': 7578, '<Null>': 4599, 'Unknown': 1978, 'Volunteer plumber': 3, "Don't know": 1, 'guma': 1, 'Trained but now deceased': 1, 'Missimg': 1, 'Hired': 1, 'under Construction': 1, 'The person is not in the village any morr': 1, 'There is a conflict with regards to mechanic NGOS are fighting to who should maintenance or touch their pump which they have installed or fixed': 1, 'dead': 1, "I don't know": 1, 'Volunteers  plumber': 1, 'Trained plumber to do maintenance': 1, 'Community Volunteer': 1, 'Not yet as the well is under construction': 1, 'No resident pump mechanic': 1, 'Yes but one is now blind and others dead': 1, 'There was a trained mechanics but the person have died 4yrs bavk': 1, 'hired mechanic': 1, 'Volunteer Plumber': 1, 'GVWC': 1, 'Hired technician': 1, 'The care taker maintains the water point': 1, 'Not applicable': 1, 'Have never  seen': 1, 'No residents mechanic': 1, 'Private own': 1}

# %%
# rescaling the maintenance features. There are 199 categories hence this will be nested
def wp_mech(x):
    if (x == 'No'):
        return 'No Mechanic' 
    elif ((x == '<Null>') | (x =='Unknown')):
        return 'Unknown'
    elif (x == 'Yes'):
        return 'Mechanic present'
    else:
        return 'OTHER'
df2['wp_mechanic'] = df2['wp_mechanic'].apply(wp_mech)
# df2.head()
print(df2['wp_mechanic'].value_counts())
# Out:
# No Mechanic         12006
# Mechanic present     7578
# Unknown              6577
# OTHER                  46
# Name: wp_mechanic, dtype: int64

# %% [markdown]
# ### WASHteam_func

# %%
print(df2['WASHteam_func'].value_counts())
# Out:
# <Null>        16424
# Yes            8425
# No             1200
# Don't know      158
# Name: WASHteam_func, dtype: int64

# %%
## replacing Null with OTHERS
df2['WASHteam_func'] = df2['WASHteam_func'].replace('<Null>', 'Don\'t know')
print(df2['WASHteam_func'].value_counts())
# Out:
# Don't know    16582
# Yes            8425
# No             1200
# Name: WASHteam_func, dtype: int64

# %% [markdown]
# #### District

# %%
### merge Falaba and Koinadugu district since survey was done before the split
## replacing Null with OTHERS
df2['District'] = df2['District'].replace('<Null>', 'Koinadugu')
print(df2['District'].value_counts())
# Out:
# Kenema           4265
# Bo               3822
# Port Loko        2780
# Western Urban    1934
# Koinadugu        1910
# Kailahun         1885
# Western Rural    1874
# Bombali          1479
# Tonkolili        1254
# Bonthe           1226
# Kono             1223
# Pujehun          1047
# Kambia            821
# Moyamba           687
# Name: District, dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# ### repair_time

# %%
## replacing Null with OTHERS
df2['repair_time'] = df2['repair_time'].replace('<Null>', 'Unknown')
print(df2['repair_time'].value_counts())
# Out:
# Water point has never broken down    8014
# Over a month                         5605
# More than a year                     5124
# I don't know                         2628
# Over a week                          2243
# Less than a week                     2146
# Unknown                               447
# Name: repair_time, dtype: int64

# %% [markdown]
# ### Adding population data by District

# %%
# creating a dictionary to assign values 
pop_dict = { "Kailahun": 526399, "Kenema": 609891, "Kono": 506100,"Bombali": 606544,
            "Kambia": 345474,"Koinadugu": 409372,"Port Loko": 615376,"Tonkolili": 531435,
            "Bo": 575478, 'Bonthe': 200781, "Moyamba": 318588,"Pujehun": 346461,"Western Rural": 444270,
            "Western Urban": 1055964}
#passing the column into a data frame
df2['Dist_pop'] = df2['District'].map(pop_dict)
print(df2['Dist_pop'].value_counts())
# Out:
# 609891     4265
# 575478     3822
# 615376     2780
# 1055964    1934
# 409372     1910
# 526399     1885
# 444270     1874
# 606544     1479
# 531435     1254
# 200781     1226
# 506100     1223
# 346461     1047
# 345474      821
# 318588      687
# Name: Dist_pop, dtype: int64

# %% [markdown]
# #### Summary of feature nesting
# |Feature||Pre processing||Post processing|
# |---||---||---|
# |wp_type||92||9|
# |extract_type||176||9|
# |pump_type||12||12|
# |wp_billed||54||6|
# |maintenance||265||12|
# |ownership||11||11|
# |wp_mech||31||4|
# |const_year||76||12|
# |WASHteam_func||4||4|

# %%
#visualize the processed dataset
print(df2.nunique().to_dict())
df2.head(2)
# Out:
# {'sub_date': 25623, 'Region': 5, 'District': 14, 'Chiefdom': 152, 'wp name': 15499, 'latitude': 25560, 'longitude': 25611, 'wp_type': 9, 'extract_type': 9, 'pump_type': 12, 'wp_func': 6, 'repair_time': 7, 'chlorination': 4, 'wp_sustain': 3, 'wp_billed': 6, 'const_year': 76, 'ownership': 11, 'maintenance': 12, 'WASH_team': 3, 'WASHteam_func': 4, 'wp_mechanic': 4, 't_toSpares?': 359, 'commu_ODF': 4, 'geometry': 26016, 'const_yr': 12, 'Dist_pop': 14}
#                    sub_date    Region   District     Chiefdom         wp name  \
# 0  30-07-2016 19:55:22 CEST  Southern     Bonthe         Dema  Community pump
# 1   01-01-2016 21:16:53 CET  Northern  Tonkolili  Kafe Simira  magburaka road
#
#    latitude  longitude           wp_type extract_type      pump_type  ...  \
# 0  7.523658 -12.500999          borewell    Hand pump  India Mark II  ...
# 1  8.860831 -11.812625  protected spring        OTHER          OTHER  ...
#
#    ownership                maintenance WASH_team WASHteam_func  \
# 0  Community              No management   Unknown        <Null>
# 1  Community  WASH management committee       Yes           Yes
#
#         wp_mechanic  t_toSpares?   commu_ODF                   geometry  \
# 0           Unknown           85  Don't know  POINT (-12.50100 7.52366)
# 1  Mechanic present          180          No  POINT (-11.81263 8.86083)
#
#       const_yr Dist_pop
# 0         2012   200781
# 1  1950 - 2000   531435
#
# [2 rows x 26 columns]

# %% [markdown]
# ## Visualising Maps
# **SL_districts**

# %%
## plot maps
## 1. sl_districts
ax = sl_dis.plot(figsize=(20,20), color ='#CCCCCC', edgecolor='#FF0000')
ctx.add_basemap(ax, crs=df2.crs)
# ax = sl_dis.plot(figsize=(20,20), color ='#CCCCCC', edgecolor='#FF0000')

# %% [markdown]
# **sl_chiefdoms**

# %%
## plot maps
## 2. sl_chiefdoms
ax = sl_chief.plot(figsize=(20,20), color ='#CCCCCC', edgecolor='blue')
ctx.add_basemap(ax, crs=df2.crs)
# ax = sl_dis.plot(figsize=(20,20), color ='#CCCCCC', edgecolor='#FF0000')

# %% [markdown]
# **Water point map by wp_type**

# %%
## plot maps
## 3. Water point maps by wp_type
ax = df2.plot(figsize=(15,15), column='wp_type', markersize = 50, edgecolor='black', legend = True)
ctx.add_basemap(ax, crs=df2.crs)
# ax = sl_dis.plot(figsize=(20,20), color ='#CCCCCC', edgecolor='#FF0000')

# %% [raw]
# #exporting file to csv for further processing
# ### note that this file type is without the geometry required for plotting on a map
# wp_joined.to_csv('water point final2.csv',index=False)
# sl_dis.to_csv('SL_Districts.csv',index=False)
# sl_chief.to_csv('SL_Chiefdoms.csv',index=False)

# %% [markdown]
# ### Saving processed data as Geopackage

# %%
## exporting to geopackage
# import fiona; help(fiona.open)

sl_dis.to_file("WP_SL.gpkg", layer='Districts', driver="GPKG")
sl_chief.to_file("WP_SL.gpkg", layer='Chiefdoms', driver="GPKG")
df2.to_file("WP_SL.gpkg", layer='Water Points', driver="GPKG")

# %% [markdown]
# ## Closing remarks
#
# The data saved will be used in the "" notebook.
#
# <hr />
# <img src="my_logo.png" style="float:center" width="80px" />
# <p><center>© 2022 <a href="http://www.Envirodatrics.com/">Envirodatrics</a> — <a href="https://creativecommons.org/licenses/by/4.0/">CC-BY</a></center></p>
