# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv (r'C:\Users\klasique computers\OneDrive\Personal development\Personal projects\WP_DaytaX.csv', encoding="ISO-8859-1")
data
# Out:
#                        Location  Latitude  Longitude  Elevation  \
# 0                  South Bonthe  7.523658 -12.500999       50.0
# 1        Tonkolili Kafe Simiria  8.860831 -11.812625      150.1
# 2          Bonthe Kwamebai Krim  7.253449 -11.895057       19.0
# 3           West  Western Urban  8.486413 -13.242527       53.0
# 4                      South Bo  7.958622 -11.754123        6.5
# ...                         ...       ...        ...        ...
# 26233    Port Loko Kaffu Bullom  8.608568 -13.184651       49.4
# 26234            Bonthe Yawbeko  7.486124 -12.169693       69.0
# 26235             South Moyamba  7.947889 -12.464489      110.0
# 26236                    Kenema  7.882070 -11.176275      184.0
# 26237  Western Rural York Rural  8.307528 -13.190608      -39.0
#
#        Type of water point  Extraction system type  Water point Functionality  \
# 0                        3                     1.0                          1
# ...

# %%
data['new_column'] = data.Location.str.findall('Kenema|Port Loko|Western Rural|Bo$|Moyamba|Tonkolili|Bonthe|Kailahun|Bombali|Kambia|Kono|Koinadugu|Pujehun|Western Urban')
data
# Out:
#                        Location  Latitude  Longitude  Elevation  \
# 0                  South Bonthe  7.523658 -12.500999       50.0
# 1        Tonkolili Kafe Simiria  8.860831 -11.812625      150.1
# 2          Bonthe Kwamebai Krim  7.253449 -11.895057       19.0
# 3           West  Western Urban  8.486413 -13.242527       53.0
# 4                      South Bo  7.958622 -11.754123        6.5
# ...                         ...       ...        ...        ...
# 26233    Port Loko Kaffu Bullom  8.608568 -13.184651       49.4
# 26234            Bonthe Yawbeko  7.486124 -12.169693       69.0
# 26235             South Moyamba  7.947889 -12.464489      110.0
# 26236                    Kenema  7.882070 -11.176275      184.0
# 26237  Western Rural York Rural  8.307528 -13.190608      -39.0
#
#        Type of water point  Extraction system type  Water point Functionality  \
# 0                        3                     1.0                          1
# ...

# %%
data['new_column'] = data.Location.str.findall('Kenema$','Port Loko$','Western Rural$','Bo$','Moyamba$'|'Tonkolili$'|'Bonthe$'|'Kailahun$'|'Bombali$'|'Kambia$'|'Kono$'|'Koinadugu$'|'Pujehun$'|'Western Urban$')
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KLASIQ~1\AppData\Local\Temp/ipykernel_6400/2156863971.py in <module>
# ----> 1 data['new_column'] = data.Location.str.findall('Kenema$'|'Port Loko$'|'Western Rural$'|'Bo$'|'Moyamba$'|'Tonkolili$'|'Bonthe$'|'Kailahun$'|'Bombali$'|'Kambia$'|'Kono$'|'Koinadugu$'|'Pujehun$'|'Western Urban$')
#       2 data
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26238 entries, 0 to 26237
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Location                                   26217 non-null  object
#  1   Latitude                                   26237 non-null  float64
#  2   Longitude                                  26237 non-null  float64
#  3   Elevation                                  26187 non-null  float64
#  4   Type of water point                        26238 non-null  int64
#  5   Extraction system type                     23260 non-null  float64
#  6   Water point Functionality                  26238 non-null  int64
#  7   Is water available throughout the year?    26238 non-null  object
#  8   Is/was this point used for drinking water  26238 non-null  int64
#  9   Year of construction                       26238 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# Location                                       21
# Latitude                                        1
# Longitude                                       1
# Elevation                                      51
# Type of water point                             0
# Extraction system type                       2978
# Water point Functionality                       0
# Is water available throughout the year?         0
# Is/was this point used for drinking water       0
# Year of construction                            0
# WP_Owner ?                                      0
# Who owns the water point?                       0
# new_column                                     21
# dtype: int64

# %%
data['Extraction system type'].describe()
# Out:
# count    23260.000000
# mean         3.416853
# std          2.714152
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          7.000000
# max          8.000000
# Name: Extraction system type, dtype: float64

# %%
data['Extraction system type'].value_counts()
# Out:
# 1.0    12148
# 7.0     6091
# 5.0     3158
# 4.0      677
# 8.0      622
# 2.0      475
# 3.0       89
# Name: Extraction system type, dtype: int64

# %%
data['Water point Functionality'].value_counts()
# Out:
# 1    17320
# 4     5078
# 3     1733
# 2     1277
# 5      683
# 6      147
# Name: Water point Functionality, dtype: int64

# %%
sns.countplot(data['Extraction system type'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.columns
# Out:
# Index(['Location', 'Latitude', 'Longitude', 'Elevation', 'Type of water point',
#        'Extraction system type', 'Water point Functionality',
#        'Is water available throughout the year?',
#        'Is/was this point used for drinking water', 'Year of construction',
#        'WP_Owner ?', 'Who owns the water point?', 'new_column'],
#       dtype='object')

# %%
features = ['Type of water point',
       'Extraction system type', 'Water point Functionality','Year of construction',
       'new_column']

# %%
list(enumerate(features))
# Out:
# [(0, 'Type of water point'),
#  (1, 'Extraction system type'),
#  (2, 'Water point Functionality'),
#  (3, 'Year of construction'),
#  (4, 'new_column')]

# %%
plt.figure(figsize = (15, 30))
for i in enumerate(features):
    plt.subplot(3, 2,i[0]+1)
    sns.countplot(i[1], data = data)
    plt.xticks(rotation = 45)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
